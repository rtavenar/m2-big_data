# %% [markdown]
# # Map-Reduce en Hadoop
#
# Dans cette séance, vous allez implémenter des Map-Reduce en Hadoop.
#
# Pour cela, le principe de fonctionnement est simple :
#
# * un premier script Python (dit _mapper_) va lire l'entrée standard (`sys.stdin` en Python) ligne par ligne et, à chaque ligne lue, afficher le résultat de l'étape de _map_ (sur la sortie standard, via un `print()`);
# * ensuite Hadoop va centraliser toutes les paires clés-valeurs émises et les trier par ordre (alphabétique) croissant ;
# * enfin, un second script Python (dit _mapper_) va lire l'entrée standard (`sys.stdin` en Python) ligne par ligne (chaque ligne correspondant donc à une paire clé-valeur émise par le _mapper_, les lignes étant triées entre elles) et, pour chaque clé, afficher sur la sortie standard le résultat de l'opération de réduction.
#
# **Attention:** pour vous assurer que tous les programmes Python que vous écrirez dans ce TD puissent s'exécuter correctement, vous vous assurerez que :
#
# 1. ils contiennent bien l'en-tête `#!/usr/bin/env python` en première ligne ;
# 2. ils disposent bien des droits d'exécution pour l'utilisateur courant.
#
# **NOTE CORRIGÉ :** les fichiers Python de mappers et de reducers sont disponibles dans l'archive <https://raw.githubusercontent.com/rtavenar/m2-big_data/main/notebooks/hadoop_mapreduce/hadoop_mapreduce_corr.zip>
#
# ## 1. Préambule : remis en route de `hadoop`
#
# Exécutez les cellules ci-dessous pour obtenir un environnement Hadoop fonctionnel.

# %%
# Télécharger et extraire hadoop

# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# Out:
# --2023-10-23 09:59:09--  https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 88.99.95.219, 135.181.214.104, 2a01:4f8:10a:201a::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|88.99.95.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 730107476 (696M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.6.tar.gz’
#
# hadoop-3.3.6.tar.gz 100%[===================>] 696.28M  27.3MB/s    in 26s
#
# 2023-10-23 09:59:35 (26.8 MB/s) - ‘hadoop-3.3.6.tar.gz’ saved [730107476/730107476]
#
# /usr/lib/jvm/java-11-openjdk-amd64

# %%
import os

os.environ["JAVA_HOME"] = os.popen("dirname $(dirname $(readlink -f $(which java)))").read().strip()
os.environ["PATH"] += ":/content/hadoop-3.3.6/bin/"

# %% [markdown]
# **Question 1.1.** Créez un dossier `/hdfs/input` sur le HDFS.

# %%
# !hadoop fs -mkdir -p /hdfs/input

# %% [markdown]
# **Question 1.2.** Téléchargez les données contenues dans l'archive <https://raw.githubusercontent.com/rtavenar/m2-big_data/main/notebooks/hadoop_mapreduce/hadoop_mapreduce_data.zip>, décompressez-les dans le dossier courant, puis copiez-les vers le dossier `/hdfs/input` du HDFS.

# %%
# !wget https://raw.githubusercontent.com/rtavenar/m2-big_data/main/notebooks/hadoop_mapreduce/hadoop_mapreduce_data.zip
# !unzip hadoop_mapreduce_data.zip

# %%
# !hadoop fs -copyFromLocal *.txt *.csv /hdfs/input
# Out:
# copyFromLocal: `/hdfs/input/CRND0103-2020-SD_Buffalo_13_ESE.txt': File exists
# copyFromLocal: `/hdfs/input/CRND0103-2021-SD_Buffalo_13_ESE.txt': File exists
# copyFromLocal: `/hdfs/input/CRND0103-2022-SD_Buffalo_13_ESE.txt': File exists
# copyFromLocal: `/hdfs/input/lorem_0.txt': File exists
# copyFromLocal: `/hdfs/input/lorem_1.txt': File exists
# copyFromLocal: `/hdfs/input/lorem_2.txt': File exists
# copyFromLocal: `/hdfs/input/lorem_3.txt': File exists
# copyFromLocal: `/hdfs/input/lorem_4.txt': File exists

# %% [markdown]
# ## 2. Premier exercice : calcul de maxima de température
#
# Le but de cette partie est d'utiliser MapReduce sur Hadoop pour obtenir la valeur maximale de température **par mois** sur les trois années 2020, 2021 et 2022 dans la ville de Buffalo.
#
# Les données correspondantes sont disponibles dans les fichiers `CRND0103-*.txt` extraits précédemment.
#
# **Question 2.1.** Ecrire un programme `mapper_Buffalo.py` permettant de découper chaque ligne récupérée sur l'entrée standard `stdin` (lignes des fichiers de données représentant des données météo journalières), et d'en extraire le mois et la température max journalière. La date est fournie en colonne 2 des fichiers et la température max en colonne 6.
#
# Le mois servira de clé intermédiaire et la température de valeur intermédiaire de sortie du `mapper`. Ces deux éléments seront imprimés sur la sortie standard séparés par une tabulation grâce à la fonction `print()`.
#
# L'entrée standard `stdin` pourra être récupérée grâce au module `sys`de Python.

# %% [markdown]
# **Question 2.2.** Pour tester votre programme `mapper_Buffalo.py`, écrire une commande Unix permettant d'afficher le contenu des fichiers de la forme `CRND0103-*.txt*.txt` (on travaille pour l'instant sur les fichiers locaux) sur la sortie standard et de passer ce contenu sur l'entrée standard du programme `mapper_Buffalo.py`.

# %%
# !chmod u+x *.py

# %%
# !cat CRND0103-*.txt | ./mapper_Buffalo.py
# Out:
# 01	8.6
# 01	5.8
# 01	2.4
# 01	9.7
# 01	4.2
# 01	4.6
# 01	0.5
# 01	-2.6
# 01	-1.7
# 01	-8.6
# 01	-9.2
# 01	4.5
# 01	-7.2
# 01	-14.1
# 01	-12.7
# 01	-7.2
# 01	0.1
# 01	-10.4
# 01	-6.3
# 01	-1.8
# 01	11.2
# 01	6.8
# 01	2.4
# 01	0.7
# 01	9.8
# 01	1.3
# 01	2.7
# 01	6.7
# 01	7.8
# 01	2.1
# 01	6.5
# 02	14.7
# 02	6.2
# 02	-2.5
# 02	-0.2
# 02	1.2
# 02	0.9
# 02	-3.3
# 02	-0.2
# 02	-2.7
# 02	-2.3
# 02	2.0
# 02	0.7
# 02	-7.7
# 02	6.0
# 02	3.4
# 02	5.9
# 02	0.0
# 02	-4.2
# 02	-5.6
# 02	4.4
# 02	10.8
# 02	10.3
# 02	6.4
# 02	1.0
# 02	-1.8
# 02	1.5
# 02	6.1
# 02	10.2
# 02	14.8
# 03	1.4
# 03	6.9
# 03	7.5
# 03	15.0
# 03	7.2
# 03	18.0
# 03	22.0
# 03	10.3
# 03	8.5
# 03	10.2
# 03	13.9
# 03	4.4
# 03	2.2
# 03	-2.7
# 03	2.3
# 03	-1.5
# 03	8.1
# 03	5.5
# 03	-0.2
# 03	-1.3
# 03	12.8
# 03	8.4
# 03	15.6
# 03	13.9
# 03	1.3
# 03	6.3
# 03	11.6
# 03	13.0
# 03	15.3
# 03	18.9
# 03	17.3
# 04	3.0
# 04	-9.0
# 04	-4.5
# 04	10.1
# 04	13.2
# 04	20.2
# 04	19.0
# 04	7.8
# 04	4.8
# 04	16.2
# 04	5.3
# 04	-3.5
# 04	-4.3
# 04	2.3
# 04	4.3
# 04	4.3
# 04	13.3
# 04	11.9
# 04	10.8
# 04	16.6
# 04	22.3
# 04	22.2
# 04	14.8
# 04	16.0
# 04	16.3
# 04	21.1
# 04	23.8
# 04	16.9
# 04	20.5
# 04	27.3
# 05	18.5
# 05	20.5
# 05	23.3
# 05	15.5
# 05	15.8
# 05	17.3
# 05	10.0
# 05	16.0
# 05	7.5
# 05	6.8
# 05	8.7
# 05	5.9
# 05	16.7
# 05	17.3
# 05	17.2
# 05	14.3
# 05	19.9
# 05	20.7
# 05	28.6
# 05	26.8
# 05	24.8
# 05	27.2
# 05	19.8
# 05	11.0
# 05	17.2
# 05	23.8
# 05	19.1
# 05	20.5
# 05	21.1
# 05	21.1
# 05	26.0
# 06	28.0
# 06	24.7
# 06	26.9
# 06	24.9
# 06	25.4
# 06	24.3
# 06	29.2
# 06	21.8
# 06	17.9
# 06	21.1
# 06	27.7
# 06	30.9
# 06	34.0
# 06	34.4
# 06	24.9
# 06	35.4
# 06	26.0
# 06	20.7
# 06	23.5
# 06	27.3
# 06	24.1
# 06	25.2
# 06	27.8
# 06	33.2
# 06	29.6
# 06	29.9
# 06	35.5
# 06	29.4
# 06	35.7
# 06	21.9
# 07	30.7
# 07	34.0
# 07	34.1
# 07	32.4
# 07	30.3
# 07	28.3
# 07	30.4
# 07	28.6
# 07	29.4
# 07	29.8
# 07	28.9
# 07	34.0
# 07	30.2
# 07	25.9
# 07	30.8
# 07	31.9
# 07	37.5
# 07	29.4
# 07	27.8
# 07	26.0
# 07	30.0
# 07	35.6
# 07	34.3
# 07	29.5
# 07	33.9
# 07	30.5
# 07	33.7
# 07	32.7
# 07	28.8
# 07	32.5
# 07	33.0
# 08	27.5
# 08	26.8
# 08	28.6
# 08	29.1
# 08	29.1
# 08	33.5
# 08	35.6
# 08	31.8
# 08	27.1
# 08	29.1
# 08	32.9
# 08	35.5
# 08	32.1
# 08	27.6
# 08	32.0
# 08	32.3
# 08	36.5
# 08	37.8
# 08	37.2
# 08	35.3
# 08	31.9
# 08	35.5
# 08	33.1
# 08	32.1
# 08	37.5
# 08	32.5
# 08	31.4
# 08	24.7
# 08	31.6
# 08	24.2
# 08	22.1
# 09	27.0
# 09	34.1
# 09	25.1
# 09	30.3
# 09	34.2
# 09	26.9
# 09	13.2
# 09	9.3
# 09	16.4
# 09	21.6
# 09	17.8
# 09	27.2
# 09	20.9
# 09	31.3
# 09	27.4
# 09	20.5
# 09	23.2
# 09	24.4
# 09	26.1
# 09	25.9
# 09	27.8
# 09	31.7
# 09	29.0
# 09	31.6
# 09	23.2
# 09	20.5
# 09	18.0
# 09	18.4
# 09	26.1
# 09	16.9
# 10	13.4
# 10	16.8
# 10	18.6
# 10	24.0
# 10	22.1
# 10	28.0
# 10	22.5
# 10	26.8
# 10	23.9
# 10	26.7
# 10	22.2
# 10	20.0
# 10	17.2
# 10	11.6
# 10	7.4
# 10	8.0
# 10	7.8
# 10	-0.2
# 10	-0.3
# 10	4.8
# 10	0.4
# 10	-2.1
# 10	-6.3
# 10	-6.5
# 10	-9.0
# 10	-8.8
# 10	5.8
# 10	4.8
# 10	11.1
# 10	17.0
# 10	9.8
# 11	15.0
# 11	23.2
# 11	24.2
# 11	23.4
# 11	25.9
# 11	19.6
# 11	17.1
# 11	15.3
# 11	-1.7
# 11	5.2
# 11	2.8
# 11	2.9
# 11	10.8
# 11	7.3
# 11	6.4
# 11	9.9
# 11	13.7
# 11	20.7
# 11	11.7
# 11	7.4
# 11	9.9
# 11	7.7
# 11	5.1
# 11	6.6
# 11	11.9
# 11	5.6
# 11	11.3
# 11	15.2
# 11	3.1
# 11	14.3
# 12	4.0
# 12	2.7
# 12	10.4
# 12	12.3
# 12	13.1
# 12	15.2
# 12	13.1
# 12	16.7
# 12	18.4
# 12	1.3
# 12	-2.7
# 12	-5.8
# 12	-4.0
# 12	-8.4
# 12	2.7
# 12	7.1
# 12	4.3
# 12	3.4
# 12	9.9
# 12	13.9
# 12	7.6
# 12	16.6
# 12	-4.9
# 12	7.7
# 12	10.5
# 12	9.6
# 12	1.9
# 12	-2.2
# 12	-0.5
# 12	2.7
# 12	8.2
# 01	9.1
# 01	9.7
# 01	8.7
# 01	8.4
# 01	6.8
# 01	7.6
# 01	-1.4
# 01	0.4
# 01	-1.2
# 01	5.6
# 01	9.3
# 01	12.7
# 01	12.5
# 01	2.6
# 01	0.8
# 01	4.5
# 01	4.5
# 01	0.2
# 01	0.6
# 01	3.7
# 01	-2.2
# 01	-0.2
# 01	-0.9
# 01	-0.5
# 01	-4.8
# 01	-8.4
# 01	-6.5
# 01	6.1
# 01	-2.1
# 01	-0.4
# 01	7.9
# 02	10.0
# 02	15.5
# 02	4.0
# 02	-3.1
# 02	-7.2
# 02	-15.8
# 02	-18.2
# 02	-16.8
# 02	-17.5
# 02	-16.4
# 02	-21.4
# 02	-21.1
# 02	-20.2
# 02	-17.7
# 02	-13.2
# 02	-13.7
# 02	-7.5
# 02	-7.3
# 02	-0.9
# 02	7.4
# 02	6.4
# 02	13.5
# 02	7.7
# 02	3.0
# 02	7.9
# 02	6.7
# 02	1.1
# 02	4.6
# 03	12.8
# 03	14.2
# 03	16.7
# 03	18.7
# 03	17.8
# 03	16.0
# 03	13.9
# 03	16.6
# 03	10.0
# 03	0.7
# 03	4.9
# 03	12.8
# 03	15.4
# 03	7.2
# 03	0.3
# 03	2.3
# 03	7.5
# 03	8.8
# 03	18.5
# 03	18.1
# 03	12.2
# 03	14.1
# 03	11.0
# 03	10.0
# 03	14.6
# 03	7.5
# 03	8.8
# 03	21.1
# 03	17.9
# 03	1.2
# 03	9.6
# 04	20.7
# 04	22.8
# 04	24.9
# 04	26.5
# 04	17.2
# 04	7.5
# 04	16.8
# 04	21.8
# 04	11.3
# 04	19.9
# 04	6.4
# 04	3.2
# 04	0.2
# 04	4.0
# 04	3.7
# 04	6.2
# 04	13.6
# 04	13.9
# 04	4.2
# 04	2.1
# 04	10.5
# 04	14.5
# 04	1.8
# 04	11.3
# 04	13.6
# 04	11.1
# 04	17.1
# 04	20.9
# 04	23.1
# 04	29.5
# 05	25.8
# 05	16.5
# 05	14.5
# 05	17.2
# 05	13.5
# 05	18.4
# 05	18.7
# 05	7.1
# 05	7.8
# 05	13.9
# 05	17.1
# 05	19.3
# 05	18.7
# 05	19.8
# 05	21.8
# 05	23.8
# 05	22.7
# 05	28.4
# 05	24.1
# 05	29.6
# 05	11.0
# 05	12.2
# 05	16.0
# 05	23.7
# 05	18.8
# 05	9.4
# 05	6.7
# 05	18.9
# 05	19.4
# 05	21.9
# 05	25.1
# 06	25.7
# 06	27.2
# 06	31.8
# 06	36.3
# 06	34.5
# 06	25.4
# 06	31.2
# 06	36.8
# 06	27.9
# 06	35.1
# 06	23.7
# 06	29.4
# 06	29.1
# 06	30.6
# 06	34.7
# 06	30.1
# 06	31.1
# 06	29.3
# 06	31.9
# 06	23.5
# 06	25.4
# 06	32.5
# 06	36.5
# 06	31.2
# 06	23.3
# 06	23.8
# 06	26.9
# 06	26.7
# 06	30.2
# 06	33.9
# 07	34.4
# 07	35.5
# 07	39.5
# 07	36.1
# 07	35.1
# 07	27.5
# 07	28.0
# 07	30.3
# 07	28.7
# 07	29.2
# 07	33.4
# 07	30.7
# 07	29.8
# 07	27.6
# 07	32.0
# 07	32.8
# 07	35.6
# 07	36.4
# 07	37.4
# 07	37.2
# 07	35.4
# 07	-9999.0
# 07	34.0
# 07	33.2
# 07	36.5
# 07	37.8
# 07	42.7
# 07	35.6
# 07	25.2
# 07	30.6
# 07	31.2
# 08	32.9
# 08	33.3
# 08	34.2
# 08	34.1
# 08	33.3
# 08	31.3
# 08	31.5
# 08	37.2
# 08	27.9
# 08	33.8
# 08	34.0
# 08	25.2
# 08	29.6
# 08	36.2
# 08	37.3
# 08	38.8
# 08	40.8
# 08	28.6
# 08	25.7
# 08	18.1
# 08	25.2
# 08	26.7
# 08	34.0
# 08	26.5
# 08	26.5
# 08	19.4
# 08	26.2
# 08	23.4
# 08	26.6
# 08	32.2
# 08	29.7
# 09	28.9
# 09	24.2
# 09	21.6
# 09	26.6
# 09	31.2
# 09	33.7
# 09	26.8
# 09	26.1
# 09	31.3
# 09	35.2
# 09	25.1
# 09	28.8
# 09	26.0
# 09	26.0
# 09	30.7
# 09	24.8
# 09	23.2
# 09	35.0
# 09	27.8
# 09	18.0
# 09	20.9
# 09	29.3
# 09	27.1
# 09	20.3
# 09	30.5
# 09	32.3
# 09	34.6
# 09	36.4
# 09	15.1
# 09	21.3
# 10	23.0
# 10	24.2
# 10	28.5
# 10	30.4
# 10	32.7
# 10	30.6
# 10	25.1
# 10	21.4
# 10	13.9
# 10	17.6
# 10	12.8
# 10	6.2
# 10	3.3
# 10	7.4
# 10	9.7
# 10	16.6
# 10	23.3
# 10	23.9
# 10	6.3
# 10	6.4
# 10	15.1
# 10	17.4
# 10	8.2
# 10	11.0
# 10	15.0
# 10	11.4
# 10	14.9
# 10	13.0
# 10	20.7
# 10	8.7
# 10	5.0
# 11	4.0
# 11	7.1
# 11	15.2
# 11	18.7
# 11	18.1
# 11	21.5
# 11	14.9
# 11	8.4
# 11	13.5
# 11	10.1
# 11	3.2
# 11	1.8
# 11	14.7
# 11	6.4
# 11	19.9
# 11	14.3
# 11	1.8
# 11	4.4
# 11	11.2
# 11	6.0
# 11	3.5
# 11	13.6
# 11	12.6
# 11	-0.6
# 11	5.1
# 11	16.8
# 11	7.0
# 11	15.8
# 11	15.7
# 11	10.9
# 12	20.9
# 12	12.1
# 12	8.3
# 12	-1.4
# 12	2.8
# 12	-5.0
# 12	-1.1
# 12	10.8
# 12	5.2
# 12	0.9
# 12	5.3
# 12	11.7
# 12	10.5
# 12	15.8
# 12	7.2
# 12	-1.0
# 12	-7.6
# 12	-5.1
# 12	8.7
# 12	-5.2
# 12	-0.2
# 12	11.0
# 12	12.7
# 12	10.2
# 12	-4.6
# 12	-6.4
# 12	-18.2
# 12	-12.2
# 12	-10.9
# 12	-8.2
# 12	-15.7
# 01	-18.3
# 01	2.0
# 01	-1.4
# 01	-1.3
# 01	-23.1
# 01	-17.9
# 01	-1.8
# 01	0.8
# 01	0.7
# 01	3.6
# 01	7.1
# 01	9.9
# 01	9.4
# 01	3.8
# 01	5.6
# 01	5.6
# 01	10.7
# 01	6.3
# 01	-13.0
# 01	-2.8
# 01	3.9
# 01	7.5
# 01	10.1
# 01	3.3
# 01	-9.6
# 01	2.5
# 01	-0.9
# 01	5.9
# 01	5.7
# 01	8.5
# 01	7.7
# 02	-9.3
# 02	-15.3
# 02	-3.0
# 02	-1.9
# 02	9.1
# 02	7.7
# 02	14.2
# 02	9.6
# 02	3.1
# 02	13.5
# 02	1.7
# 02	3.8
# 02	9.5
# 02	2.6
# 02	2.7
# 02	-3.0
# 02	4.6
# 02	3.9
# 02	14.2
# 02	9.5
# 02	-16.7
# 02	-21.6
# 02	-19.2
# 02	-14.6
# 02	-5.6
# 02	-1.7
# 02	5.8
# 02	10.0
# 03	14.4
# 03	10.6
# 03	-1.3
# 03	-0.8
# 03	-4.5
# 03	-4.0
# 03	4.1
# 03	-0.8
# 03	-7.3
# 03	-1.5
# 03	-6.7
# 03	12.6
# 03	9.0
# 03	12.9
# 03	19.3
# 03	12.5
# 03	11.9
# 03	14.7
# 03	17.2
# 03	19.9
# 03	9.7
# 03	9.7
# 03	12.7
# 03	18.6
# 03	9.2
# 03	5.2
# 03	12.4
# 03	16.9
# 03	8.8
# 03	5.1
# 03	14.2
# 04	10.2
# 04	13.7
# 04	10.4
# 04	18.1
# 04	8.7
# 04	5.4
# 04	9.2
# 04	14.3
# 04	12.9
# 04	9.3
# 04	9.7
# 04	2.1
# 04	-7.0
# 04	-5.1
# 04	-3.4
# 04	2.9
# 04	2.4
# 04	10.0
# 04	16.0
# 04	14.7
# 04	13.9
# 04	13.7
# 04	1.9
# 04	5.9
# 04	11.2
# 04	11.7
# 04	10.6
# 04	16.2
# 04	8.8
# 04	13.7
# 05	14.0
# 05	14.7
# 05	13.1
# 05	12.8
# 05	19.7
# 05	23.8
# 05	24.4
# 05	21.8
# 05	12.6
# 05	20.3
# 05	17.5
# 05	12.0
# 05	18.3
# 05	16.8
# 05	19.5
# 05	25.5
# 05	23.9
# 05	20.1
# 05	12.6
# 05	6.4
# 05	7.9
# 05	15.0
# 05	18.1
# 05	18.4
# 05	21.4
# 05	24.4
# 05	29.8
# 05	26.0
# 05	21.3
# 05	13.2
# 05	16.0
# 06	18.9
# 06	20.7
# 06	22.2
# 06	19.8
# 06	19.7
# 06	13.1
# 06	18.2
# 06	19.0
# 06	23.7
# 06	26.9
# 06	25.5
# 06	24.5
# 06	22.9
# 06	19.0
# 06	20.0
# 06	24.5
# 06	32.5
# 06	33.1
# 06	30.9
# 06	21.8
# 06	21.8
# 06	26.9
# 06	30.5
# 06	25.5
# 06	-9999.0
# 06	22.6
# 06	27.3
# 06	30.1
# 06	34.8
# 06	25.8
# 07	28.9
# 07	28.7
# 07	29.4
# 07	27.4
# 07	27.4
# 07	27.4
# 07	28.6
# 07	29.9
# 07	31.0
# 07	31.0
# 07	26.2
# 07	30.0
# 07	32.6
# 07	34.4
# 07	35.4
# 07	34.6
# 07	37.5
# 07	37.8
# 07	28.3
# 07	33.7
# 07	36.3
# 07	37.4
# 07	30.3
# 07	30.8
# 07	28.0
# 07	26.4
# 07	27.9
# 07	27.6
# 07	32.2
# 07	37.0
# 07	31.0
# 08	39.3
# 08	36.6
# 08	32.8
# 08	38.9
# 08	34.6
# 08	-9999.0

# %% [markdown]
# **Question 2.3.** Ecrire un programme `reducer_Buffalo.py` qui récupère les clés (mois) et valeurs (température max journalière) intermédiaires (issues des processus _mapper_) sur l'entrée standard `stdin` et qui calcule le maximum de température par mois. Le mois et la température max par mois seront imprimés sur la sortie standard comme clé et valeur de sortie du processus MapReduce.
#
# *Indication : utiliser le fait que le `reducer` reçoive les paires de clé et valeur intermédiaires triés par clé.*

# %% [markdown]
# **Question 2.4.** Pour tester votre programme `reducer_Buffalo.py`, écrire une commande Unix qui permet d'enchainer les traitements du `mapper` et du `reducer`.
#
# *Indication : on pourra utiliser la commande [`sort`](https://www.gnu.org/software/coreutils/manual/html_node/sort-invocation.html) de Unix pour simuler le traitement intermédiaire de tri effectué par Hadoop.*

# %%
# !cat CRND0103-*.txt | ./mapper_Buffalo.py | sort | ./reducer_Buffalo.py
# Out:
# 01	12.7
# 02	15.5
# 03	22.0
# 04	29.5
# 05	29.8
# 06	36.8
# 07	42.7
# 08	40.8
# 09	36.4
# 10	32.7
# 11	25.9
# 12	20.9

# %% [markdown]
# **Question 2.5.** Utiliser `mapred streaming` pour enchaîner les opérations, cette fois-ci en utilisant Hadoop et les fichiers localisés sur le HDFS en entrée. Vous écrirez les sorties de votre traitement dans `/hdfs/output_Buffalo`

# %%
# !mapred streaming -file mapper_Buffalo.py -mapper mapper_Buffalo.py -file reducer_Buffalo.py  -reducer reducer_Buffalo.py -input /hdfs/input/CRND0103-*.txt -output /hdfs/output_Buffalo
# Out:
# 2023-10-23 14:29:30,103 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper_Buffalo.py, reducer_Buffalo.py] [] /tmp/streamjob2083452419361744149.jar tmpDir=null
# 2023-10-23 14:29:30,980 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2023-10-23 14:29:31,139 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2023-10-23 14:29:31,139 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2023-10-23 14:29:31,157 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-10-23 14:29:31,360 INFO mapred.FileInputFormat: Total input files to process : 3
# 2023-10-23 14:29:31,386 INFO mapreduce.JobSubmitter: number of splits:3
# 2023-10-23 14:29:31,634 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1634697882_0001
# 2023-10-23 14:29:31,634 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2023-10-23 14:29:32,044 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper_Buffalo.py as file:/tmp/hadoop-root/mapred/local/job_local1634697882_0001_d907f8b2-94c0-48c2-ab27-4a78f0faa61f/mapper_Buffalo.py
# 2023-10-23 14:29:32,069 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reducer_Buffalo.py as file:/tmp/hadoop-root/mapred/local/job_local1634697882_0001_44671a24-c06b-46c9-8128-315b4c446d13/reducer_Buffalo.py
# 2023-10-23 14:29:32,169 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2023-10-23 14:29:32,171 INFO mapreduce.Job: Running job: job_local1634697882_0001
# 2023-10-23 14:29:32,183 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2023-10-23 14:29:32,185 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2023-10-23 14:29:32,192 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:29:32,192 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:29:32,246 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2023-10-23 14:29:32,252 INFO mapred.LocalJobRunner: Starting task: attempt_local1634697882_0001_m_000000_0
# 2023-10-23 14:29:32,299 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:29:32,301 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:29:32,328 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:29:32,336 INFO mapred.MapTask: Processing split: file:/hdfs/input/CRND0103-2020-SD_Buffalo_13_ESE.txt:0+79422
# 2023-10-23 14:29:32,350 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 14:29:32,467 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 14:29:32,468 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 14:29:32,468 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 14:29:32,468 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 14:29:32,468 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 14:29:32,471 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 14:29:32,481 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_Buffalo.py]
# 2023-10-23 14:29:32,487 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2023-10-23 14:29:32,488 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2023-10-23 14:29:32,489 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2023-10-23 14:29:32,489 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2023-10-23 14:29:32,490 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2023-10-23 14:29:32,490 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2023-10-23 14:29:32,491 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2023-10-23 14:29:32,491 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2023-10-23 14:29:32,492 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-10-23 14:29:32,492 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2023-10-23 14:29:32,492 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-10-23 14:29:32,493 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-10-23 14:29:32,525 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:32,526 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:32,529 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:32,588 INFO streaming.PipeMapRed: Records R/W=366/1
# 2023-10-23 14:29:32,590 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:29:32,594 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:29:32,597 INFO mapred.LocalJobRunner:
# 2023-10-23 14:29:32,597 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 14:29:32,597 INFO mapred.MapTask: Spilling map output
# 2023-10-23 14:29:32,597 INFO mapred.MapTask: bufstart = 0; bufend = 2838; bufvoid = 104857600
# 2023-10-23 14:29:32,597 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26212936(104851744); length = 1461/6553600
# 2023-10-23 14:29:32,612 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 14:29:32,625 INFO mapred.Task: Task:attempt_local1634697882_0001_m_000000_0 is done. And is in the process of committing
# 2023-10-23 14:29:32,627 INFO mapred.LocalJobRunner: Records R/W=366/1
# 2023-10-23 14:29:32,627 INFO mapred.Task: Task 'attempt_local1634697882_0001_m_000000_0' done.
# 2023-10-23 14:29:32,632 INFO mapred.Task: Final Counters for attempt_local1634697882_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=82837
# 		FILE: Number of bytes written=649940
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=366
# 		Map output records=366
# 		Map output bytes=2838
# 		Map output materialized bytes=3576
# 		Input split bytes=104
# 		Combine input records=0
# 		Spilled Records=366
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=341835776
# 	File Input Format Counters
# 		Bytes Read=80058
# 2023-10-23 14:29:32,632 INFO mapred.LocalJobRunner: Finishing task: attempt_local1634697882_0001_m_000000_0
# 2023-10-23 14:29:32,633 INFO mapred.LocalJobRunner: Starting task: attempt_local1634697882_0001_m_000001_0
# 2023-10-23 14:29:32,634 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:29:32,634 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:29:32,634 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:29:32,636 INFO mapred.MapTask: Processing split: file:/hdfs/input/CRND0103-2021-SD_Buffalo_13_ESE.txt:0+79205
# 2023-10-23 14:29:32,639 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 14:29:32,662 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 14:29:32,672 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 14:29:32,672 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 14:29:32,672 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 14:29:32,672 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 14:29:32,675 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 14:29:32,694 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_Buffalo.py]
# 2023-10-23 14:29:32,712 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:32,712 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:32,713 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:32,785 INFO streaming.PipeMapRed: Records R/W=365/1
# 2023-10-23 14:29:32,789 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:29:32,791 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:29:32,792 INFO mapred.LocalJobRunner:
# 2023-10-23 14:29:32,792 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 14:29:32,792 INFO mapred.MapTask: Spilling map output
# 2023-10-23 14:29:32,792 INFO mapred.MapTask: bufstart = 0; bufend = 2858; bufvoid = 104857600
# 2023-10-23 14:29:32,792 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26212940(104851760); length = 1457/6553600
# 2023-10-23 14:29:32,795 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 14:29:32,798 INFO mapred.Task: Task:attempt_local1634697882_0001_m_000001_0 is done. And is in the process of committing
# 2023-10-23 14:29:32,800 INFO mapred.LocalJobRunner: Records R/W=365/1
# 2023-10-23 14:29:32,800 INFO mapred.Task: Task 'attempt_local1634697882_0001_m_000001_0' done.
# 2023-10-23 14:29:32,801 INFO mapred.Task: Final Counters for attempt_local1634697882_0001_m_000001_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=163005
# 		FILE: Number of bytes written=653566
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=365
# 		Map output records=365
# 		Map output bytes=2858
# 		Map output materialized bytes=3594
# 		Input split bytes=104
# 		Combine input records=0
# 		Spilled Records=365
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=13
# 		Total committed heap usage (bytes)=341835776
# 	File Input Format Counters
# 		Bytes Read=79837
# 2023-10-23 14:29:32,802 INFO mapred.LocalJobRunner: Finishing task: attempt_local1634697882_0001_m_000001_0
# 2023-10-23 14:29:32,802 INFO mapred.LocalJobRunner: Starting task: attempt_local1634697882_0001_m_000002_0
# 2023-10-23 14:29:32,809 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:29:32,809 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:29:32,809 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:29:32,811 INFO mapred.MapTask: Processing split: file:/hdfs/input/CRND0103-2022-SD_Buffalo_13_ESE.txt:0+47306
# 2023-10-23 14:29:32,814 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 14:29:32,833 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 14:29:32,833 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 14:29:32,833 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 14:29:32,833 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 14:29:32,833 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 14:29:32,837 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 14:29:32,849 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_Buffalo.py]
# 2023-10-23 14:29:32,873 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:32,875 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:32,876 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:32,940 INFO streaming.PipeMapRed: Records R/W=218/1
# 2023-10-23 14:29:32,945 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:29:32,945 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:29:32,946 INFO mapred.LocalJobRunner:
# 2023-10-23 14:29:32,946 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 14:29:32,946 INFO mapred.MapTask: Spilling map output
# 2023-10-23 14:29:32,946 INFO mapred.MapTask: bufstart = 0; bufend = 1706; bufvoid = 104857600
# 2023-10-23 14:29:32,946 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26213528(104854112); length = 869/6553600
# 2023-10-23 14:29:32,948 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 14:29:32,954 INFO mapred.Task: Task:attempt_local1634697882_0001_m_000002_0 is done. And is in the process of committing
# 2023-10-23 14:29:32,957 INFO mapred.LocalJobRunner: Records R/W=218/1
# 2023-10-23 14:29:32,958 INFO mapred.Task: Task 'attempt_local1634697882_0001_m_000002_0' done.
# 2023-10-23 14:29:32,958 INFO mapred.Task: Final Counters for attempt_local1634697882_0001_m_000002_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=211026
# 		FILE: Number of bytes written=655746
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=218
# 		Map output records=218
# 		Map output bytes=1706
# 		Map output materialized bytes=2148
# 		Input split bytes=104
# 		Combine input records=0
# 		Spilled Records=218
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=12
# 		Total committed heap usage (bytes)=341835776
# 	File Input Format Counters
# 		Bytes Read=47690
# 2023-10-23 14:29:32,959 INFO mapred.LocalJobRunner: Finishing task: attempt_local1634697882_0001_m_000002_0
# 2023-10-23 14:29:32,959 INFO mapred.LocalJobRunner: map task executor complete.
# 2023-10-23 14:29:32,963 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2023-10-23 14:29:32,965 INFO mapred.LocalJobRunner: Starting task: attempt_local1634697882_0001_r_000000_0
# 2023-10-23 14:29:32,973 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:29:32,973 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:29:32,973 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:29:32,979 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@62c91df4
# 2023-10-23 14:29:32,981 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-10-23 14:29:33,011 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2382574336, maxSingleShuffleLimit=595643584, mergeThreshold=1572499072, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-10-23 14:29:33,013 INFO reduce.EventFetcher: attempt_local1634697882_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-10-23 14:29:33,055 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1634697882_0001_m_000000_0 decomp: 3572 len: 3576 to MEMORY
# 2023-10-23 14:29:33,058 INFO reduce.InMemoryMapOutput: Read 3572 bytes from map-output for attempt_local1634697882_0001_m_000000_0
# 2023-10-23 14:29:33,059 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 3572, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->3572
# 2023-10-23 14:29:33,063 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1634697882_0001_m_000001_0 decomp: 3590 len: 3594 to MEMORY
# 2023-10-23 14:29:33,064 INFO reduce.InMemoryMapOutput: Read 3590 bytes from map-output for attempt_local1634697882_0001_m_000001_0
# 2023-10-23 14:29:33,064 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 3590, inMemoryMapOutputs.size() -> 2, commitMemory -> 3572, usedMemory ->7162
# 2023-10-23 14:29:33,066 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1634697882_0001_m_000002_0 decomp: 2144 len: 2148 to MEMORY
# 2023-10-23 14:29:33,067 INFO reduce.InMemoryMapOutput: Read 2144 bytes from map-output for attempt_local1634697882_0001_m_000002_0
# 2023-10-23 14:29:33,067 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2144, inMemoryMapOutputs.size() -> 3, commitMemory -> 7162, usedMemory ->9306
# 2023-10-23 14:29:33,067 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2023-10-23 14:29:33,068 INFO mapred.LocalJobRunner: 3 / 3 copied.
# 2023-10-23 14:29:33,069 INFO reduce.MergeManagerImpl: finalMerge called with 3 in-memory map-outputs and 0 on-disk map-outputs
# 2023-10-23 14:29:33,075 INFO mapred.Merger: Merging 3 sorted segments
# 2023-10-23 14:29:33,075 INFO mapred.Merger: Down to the last merge-pass, with 3 segments left of total size: 9291 bytes
# 2023-10-23 14:29:33,081 INFO reduce.MergeManagerImpl: Merged 3 segments, 9306 bytes to disk to satisfy reduce memory limit
# 2023-10-23 14:29:33,082 INFO reduce.MergeManagerImpl: Merging 1 files, 9306 bytes from disk
# 2023-10-23 14:29:33,082 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2023-10-23 14:29:33,082 INFO mapred.Merger: Merging 1 sorted segments
# 2023-10-23 14:29:33,083 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 9297 bytes
# 2023-10-23 14:29:33,084 INFO mapred.LocalJobRunner: 3 / 3 copied.
# 2023-10-23 14:29:33,091 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer_Buffalo.py]
# 2023-10-23 14:29:33,093 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-10-23 14:29:33,095 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-10-23 14:29:33,114 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:33,114 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:33,117 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:29:33,166 INFO streaming.PipeMapRed: Records R/W=949/1
# 2023-10-23 14:29:33,169 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:29:33,169 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:29:33,171 INFO mapred.Task: Task:attempt_local1634697882_0001_r_000000_0 is done. And is in the process of committing
# 2023-10-23 14:29:33,174 INFO mapred.LocalJobRunner: 3 / 3 copied.
# 2023-10-23 14:29:33,174 INFO mapred.Task: Task attempt_local1634697882_0001_r_000000_0 is allowed to commit now
# 2023-10-23 14:29:33,176 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1634697882_0001_r_000000_0' to file:/hdfs/output_Buffalo
# 2023-10-23 14:29:33,176 INFO mapreduce.Job: Job job_local1634697882_0001 running in uber mode : false
# 2023-10-23 14:29:33,177 INFO mapred.LocalJobRunner: Records R/W=949/1 > reduce
# 2023-10-23 14:29:33,177 INFO mapred.Task: Task 'attempt_local1634697882_0001_r_000000_0' done.
# 2023-10-23 14:29:33,177 INFO mapreduce.Job:  map 100% reduce 100%
# 2023-10-23 14:29:33,177 INFO mapred.Task: Final Counters for attempt_local1634697882_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=229746
# 		FILE: Number of bytes written=665160
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=12
# 		Reduce shuffle bytes=9318
# 		Reduce input records=949
# 		Reduce output records=12
# 		Spilled Records=949
# 		Shuffled Maps =3
# 		Failed Shuffles=0
# 		Merged Map outputs=3
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=341835776
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=108
# 2023-10-23 14:29:33,177 INFO mapred.LocalJobRunner: Finishing task: attempt_local1634697882_0001_r_000000_0
# 2023-10-23 14:29:33,178 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2023-10-23 14:29:34,179 INFO mapreduce.Job: Job job_local1634697882_0001 completed successfully
# 2023-10-23 14:29:34,192 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=686614
# 		FILE: Number of bytes written=2624412
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=949
# 		Map output records=949
# 		Map output bytes=7402
# 		Map output materialized bytes=9318
# 		Input split bytes=312
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=12
# 		Reduce shuffle bytes=9318
# 		Reduce input records=949
# 		Reduce output records=12
# 		Spilled Records=1898
# 		Shuffled Maps =3
# 		Failed Shuffles=0
# 		Merged Map outputs=3
# 		GC time elapsed (ms)=25
# 		Total committed heap usage (bytes)=1367343104
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=207585
# 	File Output Format Counters
# 		Bytes Written=108
# 2023-10-23 14:29:34,193 INFO streaming.StreamJob: Output directory: /hdfs/output_Buffalo

# %% [markdown]
# **Question 2.6.** Comment s'appelle le fichier dans lesquel a été écrit le résultat ? Affichez son contenu.

# %%
# !hadoop fs -ls /hdfs/output_Buffalo
# Out:
# Found 2 items
# -rw-r--r--   1 root root          0 2023-10-23 14:29 /hdfs/output_Buffalo/_SUCCESS
# -rw-r--r--   1 root root         96 2023-10-23 14:29 /hdfs/output_Buffalo/part-00000

# %%
# !hadoop fs -cat /hdfs/output_Buffalo/part-00000
# Out:
# 01	12.7
# 02	15.5
# 03	22.0
# 04	29.5
# 05	29.8
# 06	36.8
# 07	42.7
# 08	40.8
# 09	36.4
# 10	32.7
# 11	25.9
# 12	20.9

# %% [markdown]
# ## 3. Deuxième exercice : _wordcount_
#
# Dans cette partie, vous devrez implémenter un wordcount **en Hadoop MapReduce**.
#
# Pour cela vous devrez :
#
# * travailler sur les fichiers `lorem_*.txt` ;
# * implémenter un `mapper_wordcount.py` qui affichera, pour chaque mot lu, une sortie du type `le_mot_lu 1` ;
# * implémenter un `reducer_wordcount.py` qui fera la somme des comptes mot par mot ;
# * afficher le résultat pour vous assurer que tout a bien fonctionné.

# %%
# !chmod u+x *.py

# %%
# !cat lorem_*.txt | ./mapper_wordcount.py
# Out:
# Commodi 1
# ratione 1
# explicabo 1
# saepe 1
# accusantium 1
# voluptas 1
# illum 1
# rem 1
# assumenda 1
# rerum 1
# delectus 1
# saepe 1
# sit 1
# doloribus 1
# quos 1
# nulla 1
# praesentium 1
# voluptatibus 1
# accusantium 1
# Perspiciatis 1
# voluptatibus 1
# optio 1
# maiores 1
# dignissimos 1
# veniam 1
# at 1
# magni 1
# quo 1
# similique 1
# similique 1
# omnis 1
# quo 1
# enim 1
# aperiam 1
# quae 1
# ipsum 1
# earum 1
# cumque 1
# inventore 1
# natus 1
# omnis 1
# beatae 1
# rerum 1
# similique 1
# porro 1
# deserunt 1
# exercitationem 1
# rem 1
# hic?Consequatur 1
# blanditiis 1
# reiciendis 1
# rem 1
# repellat 1
# dolore 1
# quod 1
# vel 1
# nam 1
# placeat 1
# cumque 1
# cum 1
# illum 1
# voluptate 1
# Soluta 1
# alias 1
# eum 1
# illum 1
# dolor 1
# cupiditate 1
# dolores 1
# praesentium 1
# neque 1
# aperiam 1
# incidunt 1
# adipisci 1
# maiores 1
# earum 1
# quia 1
# rem 1
# natus 1
# necessitatibus 1
# nihil 1
# labore 1
# reprehenderit?Quia 1
# aliquid 1
# nostrum 1
# ab 1
# eum 1
# excepturi 1
# architecto 1
# autem 1
# incidunt 1
# recusandae 1
# facere 1
# voluptates 1
# architecto 1
# temporibus 1
# animi 1
# provident 1
# error 1
# eos 1
# vitae 1
# facilis 1
# laudantium 1
# quod 1
# veniam 1
# dolorum 1
# explicabo 1
# velit 1
# earum 1
# odio 1
# corrupti 1
# expedita 1
# ea 1
# ratione 1
# Possimus 1
# in 1
# sed 1
# repellat 1
# tempore 1
# quam 1
# molestiae 1
# repudiandae 1
# minima 1
# assumenda 1
# est 1
# asperiores 1
# numquam 1
# nulla 1
# corrupti 1
# corporis 1
# sint 1
# tempora 1
# doloremque 1
# quo 1
# autem 1
# repellendus 1
# ab 1
# pariatur 1
# libero 1
# impedit 1
# ullam 1
# molestiae 1
# laudantium 1
# eius 1
# incidunt 1
# sequi 1
# excepturi 1
# dolor 1
# unde 1
# temporibus 1
# mollitia 1
# Delectus 1
# officia 1
# eum 1
# similique 1
# repellendus 1
# animi 1
# natus 1
# libero 1
# unde 1
# sed 1
# vitae 1
# soluta 1
# dolores 1
# fugit 1
# ab 1
# vel 1
# nihil 1
# numquam 1
# enim 1
# doloribus 1
# asperiores 1
# voluptatum 1
# itaque 1
# minima 1
# quae 1
# nihil 1
# beatae 1
# quo 1
# voluptatibus 1
# ducimus 1
# pariatur 1
# reprehenderit 1
# blanditiis 1
# dignissimos 1
# natus 1
# perspiciatis 1
# ipsum 1
# sint 1
# unde 1
# est 1
# culpa 1
# ea 1
# minus 1
# vel 1
# voluptas 1
# vitae 1
# omnis 1
# sit 1
# voluptatibus 1
# molestiae? 1
# Assumenda 1
# quam 1
# veritatis 1
# est 1
# nam 1
# beatae 1
# aliquid 1
# tempora 1
# officia 1
# consectetur 1
# possimus 1
# mollitia 1
# deleniti 1
# accusamus 1
# hicBeatae 1
# obcaecati 1
# libero 1
# asperiores 1
# pariatur 1
# dolor 1
# expedita 1
# dolore 1
# odit 1
# est 1
# necessitatibus 1
# minima 1
# id 1
# quia 1
# maiores 1
# mollitia 1
# pariatur 1
# inventore 1
# Nesciunt 1
# nihil 1
# sit 1
# officia 1
# nam 1
# quaerat 1
# veritatis 1
# nisi 1
# officiis 1
# aliquam 1
# sed 1
# saepe 1
# fuga 1
# nisi 1
# blanditiis 1
# aperiam 1
# tempora 1
# amet 1
# ipsam 1
# quas 1
# officia 1
# delectus 1
# porro 1
# quis 1
# vel 1
# alias 1
# tempore 1
# quam 1
# amet 1
# animi 1
# temporibus 1
# voluptates 1
# repellendus? 1
# Laboriosam 1
# dicta 1
# beatae 1
# praesentium 1
# amet 1
# ex 1
# tempore 1
# laboriosam 1
# dolore 1
# dolor 1
# corporis 1
# aperiam 1
# sit 1
# saepe 1
# deserunt 1
# sed 1
# Iusto 1
# eligendi 1
# perferendis 1
# tempore 1
# incidunt 1
# cumque 1
# ea 1
# iste 1
# tempore 1
# eveniet 1
# quo 1
# culpa 1
# atque 1
# ducimus 1
# repellat 1
# reprehenderit 1
# consectetur 1
# aliquam 1
# magni 1
# totam 1
# delectus 1
# impedit 1
# natus 1
# ratione 1
# blanditiis 1
# excepturi 1
# harumTempora 1
# fuga 1
# voluptates 1
# nisi 1
# maiores 1
# quod 1
# error 1
# facere 1
# aut 1
# temporibus 1
# fugiat 1
# explicabo 1
# provident 1
# dolor 1
# nemo 1
# modi 1
# eligendi 1
# est 1
# eos 1
# corporis 1
# minus 1
# illum 1
# necessitatibus 1
# voluptates 1
# inventore 1
# deserunt 1
# eaque 1
# voluptas 1
# at 1
# voluptatum 1
# dignissimos 1
# quo 1
# magni 1
# odio 1
# numquam 1
# quasi 1
# eos 1
# repellendus? 1
# Repellat 1
# mollitia 1
# laboriosam 1
# nobis 1
# omnis 1
# voluptatum 1
# alias 1
# id 1
# odit 1
# a 1
# error 1
# laborum 1
# mollitia 1
# id 1
# deleniti 1
# repellat 1
# ea 1
# provident 1
# exercitationem 1
# voluptas 1
# facere 1
# distinctio 1
# dignissimos 1
# vitae 1
# voluptatum 1
# esse 1
# earum 1
# Aperiam 1
# ab 1
# libero 1
# voluptate 1
# at 1
# nam 1
# tempora 1
# consequuntur 1
# perspiciatis 1
# sint 1
# a 1
# ea 1
# earum 1
# eos 1
# quaerat 1
# quisquam 1
# mollitia 1
# vel 1
# hic 1
# nulla? 1
# Dolor 1
# tenetur 1
# possimus 1
# provident 1
# quisquam 1
# ex 1
# autem 1
# obcaecati 1
# ad 1
# cupiditate 1
# culpa 1
# magnam 1
# cumque 1
# molestiae 1
# quae 1
# suscipit 1
# vel 1
# reiciendis 1
# minus 1
# provident 1
# temporibus 1
# doloremque 1
# explicabo 1
# laboriosam 1
# nihil 1
# veritatis 1
# pariatur 1
# inventore 1

# %%
# !cat lorem_*.txt | ./mapper_wordcount.py | sort | ./reducer_wordcount.py
# Out:
# a	2
# ab	4
# accusamus	1
# accusantium	2
# ad	1
# adipisci	1
# alias	3
# aliquam	2
# aliquid	2
# amet	3
# animi	3
# aperiam	4
# Aperiam	1
# architecto	2
# asperiores	3
# assumenda	2
# Assumenda	1
# at	3
# atque	1
# aut	1
# autem	3
# beatae	4
# blanditiis	4
# Commodi	1
# consectetur	2
# consequuntur	1
# corporis	3
# corrupti	2
# culpa	3
# cum	1
# cumque	4
# cupiditate	2
# delectus	3
# Delectus	1
# deleniti	2
# deserunt	3
# dicta	1
# dignissimos	4
# distinctio	1
# dolor	5
# Dolor	1
# dolore	3
# doloremque	2
# dolores	2
# doloribus	2
# dolorum	1
# ducimus	2
# ea	5
# eaque	1
# earum	5
# eius	1
# eligendi	2
# enim	2
# eos	4
# error	3
# esse	1
# est	5
# eum	3
# eveniet	1
# ex	2
# excepturi	3
# exercitationem	2
# expedita	2
# explicabo	4
# facere	3
# facilis	1
# fuga	2
# fugiat	1
# fugit	1
# harumTempora	1
# hic	1
# hicBeatae	1
# hic?Consequatur	1
# id	3
# illum	4
# impedit	2
# in	1
# incidunt	4
# inventore	4
# ipsam	1
# ipsum	2
# iste	1
# itaque	1
# Iusto	1
# labore	1
# laboriosam	3
# Laboriosam	1
# laborum	1
# laudantium	2
# libero	4
# magnam	1
# magni	3
# maiores	4
# minima	3
# minus	3
# modi	1
# molestiae	3
# molestiae?	1
# mollitia	6
# nam	4
# natus	5
# necessitatibus	3
# nemo	1
# neque	1
# Nesciunt	1
# nihil	5
# nisi	3
# nobis	1
# nostrum	1
# nulla	2
# nulla?	1
# numquam	3
# obcaecati	2
# odio	2
# odit	2
# officia	4
# officiis	1
# omnis	4
# optio	1
# pariatur	5
# perferendis	1
# perspiciatis	2
# Perspiciatis	1
# placeat	1
# porro	2
# possimus	2
# Possimus	1
# praesentium	3
# provident	5
# quae	3
# quaerat	2
# quam	3
# quas	1
# quasi	1
# quia	2
# quis	1
# quisquam	2
# quo	6
# quod	3
# quos	1
# ratione	3
# recusandae	1
# reiciendis	2
# rem	4
# repellat	4
# Repellat	1
# repellendus	2
# repellendus?	2
# reprehenderit	2
# reprehenderit?Quia	1
# repudiandae	1
# rerum	2
# saepe	4
# sed	4
# sequi	1
# similique	4
# sint	3
# sit	4
# soluta	1
# Soluta	1
# suscipit	1
# tempora	4
# tempore	5
# temporibus	5
# tenetur	1
# totam	1
# ullam	1
# unde	3
# vel	6
# velit	1
# veniam	2
# veritatis	3
# vitae	4
# voluptas	4
# voluptate	2
# voluptates	4
# voluptatibus	4
# voluptatum	4

# %%
# !mapred streaming -file mapper_wordcount.py -mapper mapper_wordcount.py -file reducer_wordcount.py  -reducer reducer_wordcount.py -input /hdfs/input/lorem_*.txt -output /hdfs/output_wordcount
# Out:
# 2023-10-23 14:31:15,748 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper_wordcount.py, reducer_wordcount.py] [] /tmp/streamjob14994637074962929923.jar tmpDir=null
# 2023-10-23 14:31:16,339 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2023-10-23 14:31:16,512 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2023-10-23 14:31:16,513 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2023-10-23 14:31:16,529 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-10-23 14:31:16,697 INFO mapred.FileInputFormat: Total input files to process : 5
# 2023-10-23 14:31:16,720 INFO mapreduce.JobSubmitter: number of splits:5
# 2023-10-23 14:31:16,978 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local288181184_0001
# 2023-10-23 14:31:16,979 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2023-10-23 14:31:17,344 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper_wordcount.py as file:/tmp/hadoop-root/mapred/local/job_local288181184_0001_8599a2ea-9d37-45aa-ba28-6381ae305ccd/mapper_wordcount.py
# 2023-10-23 14:31:17,374 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reducer_wordcount.py as file:/tmp/hadoop-root/mapred/local/job_local288181184_0001_0e2e4286-fa49-44cf-b073-5b16ceefe911/reducer_wordcount.py
# 2023-10-23 14:31:17,505 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2023-10-23 14:31:17,507 INFO mapreduce.Job: Running job: job_local288181184_0001
# 2023-10-23 14:31:17,512 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2023-10-23 14:31:17,516 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2023-10-23 14:31:17,521 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:31:17,521 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:31:17,572 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2023-10-23 14:31:17,576 INFO mapred.LocalJobRunner: Starting task: attempt_local288181184_0001_m_000000_0
# 2023-10-23 14:31:17,618 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:31:17,621 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:31:17,644 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:31:17,656 INFO mapred.MapTask: Processing split: file:/hdfs/input/lorem_2.txt:0+1024
# 2023-10-23 14:31:17,670 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 14:31:17,819 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 14:31:17,819 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 14:31:17,819 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 14:31:17,819 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 14:31:17,819 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 14:31:17,823 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 14:31:17,832 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_wordcount.py]
# 2023-10-23 14:31:17,839 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2023-10-23 14:31:17,840 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2023-10-23 14:31:17,840 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2023-10-23 14:31:17,841 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2023-10-23 14:31:17,841 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2023-10-23 14:31:17,841 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2023-10-23 14:31:17,842 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2023-10-23 14:31:17,843 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2023-10-23 14:31:17,843 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-10-23 14:31:17,843 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2023-10-23 14:31:17,844 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-10-23 14:31:17,844 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-10-23 14:31:17,872 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:31:17,920 INFO streaming.PipeMapRed: Records R/W=1/1
# 2023-10-23 14:31:17,926 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:31:17,927 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:31:17,930 INFO mapred.LocalJobRunner:
# 2023-10-23 14:31:17,930 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 14:31:17,930 INFO mapred.MapTask: Spilling map output
# 2023-10-23 14:31:17,930 INFO mapred.MapTask: bufstart = 0; bufend = 1412; bufvoid = 104857600
# 2023-10-23 14:31:17,930 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26213864(104855456); length = 533/6553600
# 2023-10-23 14:31:17,950 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 14:31:17,965 INFO mapred.Task: Task:attempt_local288181184_0001_m_000000_0 is done. And is in the process of committing
# 2023-10-23 14:31:17,967 INFO mapred.LocalJobRunner: Records R/W=1/1
# 2023-10-23 14:31:17,967 INFO mapred.Task: Task 'attempt_local288181184_0001_m_000000_0' done.
# 2023-10-23 14:31:17,973 INFO mapred.Task: Final Counters for attempt_local288181184_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=3718
# 		FILE: Number of bytes written=644839
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=134
# 		Map output bytes=1412
# 		Map output materialized bytes=1686
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=134
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=17
# 		Total committed heap usage (bytes)=330301440
# 	File Input Format Counters
# 		Bytes Read=1040
# 2023-10-23 14:31:17,973 INFO mapred.LocalJobRunner: Finishing task: attempt_local288181184_0001_m_000000_0
# 2023-10-23 14:31:17,974 INFO mapred.LocalJobRunner: Starting task: attempt_local288181184_0001_m_000001_0
# 2023-10-23 14:31:17,975 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:31:17,975 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:31:17,975 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:31:17,977 INFO mapred.MapTask: Processing split: file:/hdfs/input/lorem_4.txt:0+860
# 2023-10-23 14:31:17,980 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 14:31:17,992 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 14:31:17,992 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 14:31:17,992 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 14:31:17,992 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 14:31:17,992 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 14:31:17,993 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 14:31:17,997 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_wordcount.py]
# 2023-10-23 14:31:18,036 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:31:18,093 INFO streaming.PipeMapRed: Records R/W=1/1
# 2023-10-23 14:31:18,099 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:31:18,099 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:31:18,099 INFO mapred.LocalJobRunner:
# 2023-10-23 14:31:18,100 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 14:31:18,100 INFO mapred.MapTask: Spilling map output
# 2023-10-23 14:31:18,100 INFO mapred.MapTask: bufstart = 0; bufend = 1187; bufvoid = 104857600
# 2023-10-23 14:31:18,100 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26213948(104855792); length = 449/6553600
# 2023-10-23 14:31:18,102 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 14:31:18,108 INFO mapred.Task: Task:attempt_local288181184_0001_m_000001_0 is done. And is in the process of committing
# 2023-10-23 14:31:18,109 INFO mapred.LocalJobRunner: Records R/W=1/1
# 2023-10-23 14:31:18,109 INFO mapred.Task: Task 'attempt_local288181184_0001_m_000001_0' done.
# 2023-10-23 14:31:18,110 INFO mapred.Task: Final Counters for attempt_local288181184_0001_m_000001_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=5021
# 		FILE: Number of bytes written=646290
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=113
# 		Map output bytes=1187
# 		Map output materialized bytes=1419
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=113
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=5
# 		Total committed heap usage (bytes)=330301440
# 	File Input Format Counters
# 		Bytes Read=884
# 2023-10-23 14:31:18,110 INFO mapred.LocalJobRunner: Finishing task: attempt_local288181184_0001_m_000001_0
# 2023-10-23 14:31:18,110 INFO mapred.LocalJobRunner: Starting task: attempt_local288181184_0001_m_000002_0
# 2023-10-23 14:31:18,111 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:31:18,111 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:31:18,112 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:31:18,113 INFO mapred.MapTask: Processing split: file:/hdfs/input/lorem_3.txt:0+713
# 2023-10-23 14:31:18,116 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 14:31:18,132 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 14:31:18,132 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 14:31:18,132 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 14:31:18,132 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 14:31:18,132 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 14:31:18,139 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 14:31:18,147 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_wordcount.py]
# 2023-10-23 14:31:18,173 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:31:18,242 INFO streaming.PipeMapRed: Records R/W=1/1
# 2023-10-23 14:31:18,250 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:31:18,251 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:31:18,251 INFO mapred.LocalJobRunner:
# 2023-10-23 14:31:18,252 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 14:31:18,252 INFO mapred.MapTask: Spilling map output
# 2023-10-23 14:31:18,252 INFO mapred.MapTask: bufstart = 0; bufend = 982; bufvoid = 104857600
# 2023-10-23 14:31:18,252 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214024(104856096); length = 373/6553600
# 2023-10-23 14:31:18,254 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 14:31:18,261 INFO mapred.Task: Task:attempt_local288181184_0001_m_000002_0 is done. And is in the process of committing
# 2023-10-23 14:31:18,263 INFO mapred.LocalJobRunner: Records R/W=1/1
# 2023-10-23 14:31:18,263 INFO mapred.Task: Task 'attempt_local288181184_0001_m_000002_0' done.
# 2023-10-23 14:31:18,264 INFO mapred.Task: Final Counters for attempt_local288181184_0001_m_000002_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=6177
# 		FILE: Number of bytes written=647498
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=94
# 		Map output bytes=982
# 		Map output materialized bytes=1176
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=94
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=5
# 		Total committed heap usage (bytes)=330301440
# 	File Input Format Counters
# 		Bytes Read=737
# 2023-10-23 14:31:18,264 INFO mapred.LocalJobRunner: Finishing task: attempt_local288181184_0001_m_000002_0
# 2023-10-23 14:31:18,264 INFO mapred.LocalJobRunner: Starting task: attempt_local288181184_0001_m_000003_0
# 2023-10-23 14:31:18,266 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:31:18,266 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:31:18,267 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:31:18,271 INFO mapred.MapTask: Processing split: file:/hdfs/input/lorem_0.txt:0+383
# 2023-10-23 14:31:18,277 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 14:31:18,288 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 14:31:18,289 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 14:31:18,289 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 14:31:18,289 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 14:31:18,289 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 14:31:18,289 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 14:31:18,295 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_wordcount.py]
# 2023-10-23 14:31:18,327 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:31:18,371 INFO streaming.PipeMapRed: Records R/W=1/1
# 2023-10-23 14:31:18,374 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:31:18,375 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:31:18,375 INFO mapred.LocalJobRunner:
# 2023-10-23 14:31:18,375 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 14:31:18,375 INFO mapred.MapTask: Spilling map output
# 2023-10-23 14:31:18,375 INFO mapred.MapTask: bufstart = 0; bufend = 526; bufvoid = 104857600
# 2023-10-23 14:31:18,375 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214204(104856816); length = 193/6553600
# 2023-10-23 14:31:18,377 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 14:31:18,384 INFO mapred.Task: Task:attempt_local288181184_0001_m_000003_0 is done. And is in the process of committing
# 2023-10-23 14:31:18,385 INFO mapred.LocalJobRunner: Records R/W=1/1
# 2023-10-23 14:31:18,386 INFO mapred.Task: Task 'attempt_local288181184_0001_m_000003_0' done.
# 2023-10-23 14:31:18,386 INFO mapred.Task: Final Counters for attempt_local288181184_0001_m_000003_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=6999
# 		FILE: Number of bytes written=648160
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=49
# 		Map output bytes=526
# 		Map output materialized bytes=630
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=49
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=3
# 		Total committed heap usage (bytes)=330301440
# 	File Input Format Counters
# 		Bytes Read=403
# 2023-10-23 14:31:18,386 INFO mapred.LocalJobRunner: Finishing task: attempt_local288181184_0001_m_000003_0
# 2023-10-23 14:31:18,386 INFO mapred.LocalJobRunner: Starting task: attempt_local288181184_0001_m_000004_0
# 2023-10-23 14:31:18,387 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:31:18,387 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:31:18,388 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:31:18,392 INFO mapred.MapTask: Processing split: file:/hdfs/input/lorem_1.txt:0+268
# 2023-10-23 14:31:18,396 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 14:31:18,411 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 14:31:18,411 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 14:31:18,411 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 14:31:18,411 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 14:31:18,411 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 14:31:18,420 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 14:31:18,425 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_wordcount.py]
# 2023-10-23 14:31:18,446 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:31:18,508 INFO streaming.PipeMapRed: Records R/W=1/1
# 2023-10-23 14:31:18,511 INFO mapreduce.Job: Job job_local288181184_0001 running in uber mode : false
# 2023-10-23 14:31:18,513 INFO mapreduce.Job:  map 100% reduce 0%
# 2023-10-23 14:31:18,519 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:31:18,520 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:31:18,520 INFO mapred.LocalJobRunner:
# 2023-10-23 14:31:18,520 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 14:31:18,520 INFO mapred.MapTask: Spilling map output
# 2023-10-23 14:31:18,521 INFO mapred.MapTask: bufstart = 0; bufend = 371; bufvoid = 104857600
# 2023-10-23 14:31:18,521 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214260(104857040); length = 137/6553600
# 2023-10-23 14:31:18,522 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 14:31:18,529 INFO mapred.Task: Task:attempt_local288181184_0001_m_000004_0 is done. And is in the process of committing
# 2023-10-23 14:31:18,531 INFO mapred.LocalJobRunner: Records R/W=1/1
# 2023-10-23 14:31:18,531 INFO mapred.Task: Task 'attempt_local288181184_0001_m_000004_0' done.
# 2023-10-23 14:31:18,531 INFO mapred.Task: Final Counters for attempt_local288181184_0001_m_000004_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=7706
# 		FILE: Number of bytes written=648639
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1
# 		Map output records=35
# 		Map output bytes=371
# 		Map output materialized bytes=447
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=35
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=330301440
# 	File Input Format Counters
# 		Bytes Read=288
# 2023-10-23 14:31:18,531 INFO mapred.LocalJobRunner: Finishing task: attempt_local288181184_0001_m_000004_0
# 2023-10-23 14:31:18,533 INFO mapred.LocalJobRunner: map task executor complete.
# 2023-10-23 14:31:18,536 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2023-10-23 14:31:18,536 INFO mapred.LocalJobRunner: Starting task: attempt_local288181184_0001_r_000000_0
# 2023-10-23 14:31:18,549 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 14:31:18,549 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 14:31:18,550 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 14:31:18,555 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@7d710971
# 2023-10-23 14:31:18,556 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-10-23 14:31:18,572 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2382574336, maxSingleShuffleLimit=595643584, mergeThreshold=1572499072, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-10-23 14:31:18,574 INFO reduce.EventFetcher: attempt_local288181184_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-10-23 14:31:18,623 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local288181184_0001_m_000000_0 decomp: 1682 len: 1686 to MEMORY
# 2023-10-23 14:31:18,627 INFO reduce.InMemoryMapOutput: Read 1682 bytes from map-output for attempt_local288181184_0001_m_000000_0
# 2023-10-23 14:31:18,631 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1682, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->1682
# 2023-10-23 14:31:18,636 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local288181184_0001_m_000003_0 decomp: 626 len: 630 to MEMORY
# 2023-10-23 14:31:18,640 INFO reduce.InMemoryMapOutput: Read 626 bytes from map-output for attempt_local288181184_0001_m_000003_0
# 2023-10-23 14:31:18,640 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 626, inMemoryMapOutputs.size() -> 2, commitMemory -> 1682, usedMemory ->2308
# 2023-10-23 14:31:18,642 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local288181184_0001_m_000002_0 decomp: 1172 len: 1176 to MEMORY
# 2023-10-23 14:31:18,645 INFO reduce.InMemoryMapOutput: Read 1172 bytes from map-output for attempt_local288181184_0001_m_000002_0
# 2023-10-23 14:31:18,645 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1172, inMemoryMapOutputs.size() -> 3, commitMemory -> 2308, usedMemory ->3480
# 2023-10-23 14:31:18,647 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local288181184_0001_m_000004_0 decomp: 443 len: 447 to MEMORY
# 2023-10-23 14:31:18,648 INFO reduce.InMemoryMapOutput: Read 443 bytes from map-output for attempt_local288181184_0001_m_000004_0
# 2023-10-23 14:31:18,649 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 443, inMemoryMapOutputs.size() -> 4, commitMemory -> 3480, usedMemory ->3923
# 2023-10-23 14:31:18,650 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local288181184_0001_m_000001_0 decomp: 1415 len: 1419 to MEMORY
# 2023-10-23 14:31:18,651 INFO reduce.InMemoryMapOutput: Read 1415 bytes from map-output for attempt_local288181184_0001_m_000001_0
# 2023-10-23 14:31:18,652 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1415, inMemoryMapOutputs.size() -> 5, commitMemory -> 3923, usedMemory ->5338
# 2023-10-23 14:31:18,654 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2023-10-23 14:31:18,655 INFO mapred.LocalJobRunner: 5 / 5 copied.
# 2023-10-23 14:31:18,655 INFO reduce.MergeManagerImpl: finalMerge called with 5 in-memory map-outputs and 0 on-disk map-outputs
# 2023-10-23 14:31:18,660 INFO mapred.Merger: Merging 5 sorted segments
# 2023-10-23 14:31:18,661 INFO mapred.Merger: Down to the last merge-pass, with 5 segments left of total size: 5273 bytes
# 2023-10-23 14:31:18,667 INFO reduce.MergeManagerImpl: Merged 5 segments, 5338 bytes to disk to satisfy reduce memory limit
# 2023-10-23 14:31:18,667 INFO reduce.MergeManagerImpl: Merging 1 files, 5334 bytes from disk
# 2023-10-23 14:31:18,667 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2023-10-23 14:31:18,667 INFO mapred.Merger: Merging 1 sorted segments
# 2023-10-23 14:31:18,668 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 5318 bytes
# 2023-10-23 14:31:18,668 INFO mapred.LocalJobRunner: 5 / 5 copied.
# 2023-10-23 14:31:18,672 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer_wordcount.py]
# 2023-10-23 14:31:18,674 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-10-23 14:31:18,676 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-10-23 14:31:18,688 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:31:18,688 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:31:18,690 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 14:31:18,742 INFO streaming.PipeMapRed: Records R/W=425/1
# 2023-10-23 14:31:18,745 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 14:31:18,746 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 14:31:18,747 INFO mapred.Task: Task:attempt_local288181184_0001_r_000000_0 is done. And is in the process of committing
# 2023-10-23 14:31:18,748 INFO mapred.LocalJobRunner: 5 / 5 copied.
# 2023-10-23 14:31:18,748 INFO mapred.Task: Task attempt_local288181184_0001_r_000000_0 is allowed to commit now
# 2023-10-23 14:31:18,749 INFO output.FileOutputCommitter: Saved output of task 'attempt_local288181184_0001_r_000000_0' to file:/hdfs/output_wordcount
# 2023-10-23 14:31:18,750 INFO mapred.LocalJobRunner: Records R/W=425/1 > reduce
# 2023-10-23 14:31:18,750 INFO mapred.Task: Task 'attempt_local288181184_0001_r_000000_0' done.
# 2023-10-23 14:31:18,750 INFO mapred.Task: Final Counters for attempt_local288181184_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=18558
# 		FILE: Number of bytes written=655743
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=181
# 		Reduce shuffle bytes=5358
# 		Reduce input records=425
# 		Reduce output records=181
# 		Spilled Records=425
# 		Shuffled Maps =5
# 		Failed Shuffles=0
# 		Merged Map outputs=5
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=330301440
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=1770
# 2023-10-23 14:31:18,750 INFO mapred.LocalJobRunner: Finishing task: attempt_local288181184_0001_r_000000_0
# 2023-10-23 14:31:18,750 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2023-10-23 14:31:19,516 INFO mapreduce.Job:  map 100% reduce 100%
# 2023-10-23 14:31:19,517 INFO mapreduce.Job: Job job_local288181184_0001 completed successfully
# 2023-10-23 14:31:19,528 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=48179
# 		FILE: Number of bytes written=3891169
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=5
# 		Map output records=425
# 		Map output bytes=4478
# 		Map output materialized bytes=5358
# 		Input split bytes=400
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=181
# 		Reduce shuffle bytes=5358
# 		Reduce input records=425
# 		Reduce output records=181
# 		Spilled Records=850
# 		Shuffled Maps =5
# 		Failed Shuffles=0
# 		Merged Map outputs=5
# 		GC time elapsed (ms)=34
# 		Total committed heap usage (bytes)=1981808640
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=3352
# 	File Output Format Counters
# 		Bytes Written=1770
# 2023-10-23 14:31:19,528 INFO streaming.StreamJob: Output directory: /hdfs/output_wordcount

# %%
# !hadoop fs -cat /hdfs/output_wordcount/part-00000
# Out:
# Aperiam	1
# Assumenda	1
# Beatae	1
# Commodi	1
# Consequatur	1
# Delectus	1
# Dolor	1
# Iusto	1
# Laboriosam	1
# Nesciunt	1
# Perspiciatis	1
# Possimus	1
# Quia	1
# Repellat	1
# Soluta	1
# Tempora	1
# a	2
# ab	4
# accusamus	1
# accusantium	2
# ad	1
# adipisci	1
# alias	3
# aliquam	2
# aliquid	2
# amet	3
# animi	3
# aperiam	4
# architecto	2
# asperiores	3
# assumenda	2
# at	3
# atque	1
# aut	1
# autem	3
# beatae	4
# blanditiis	4
# consectetur	2
# consequuntur	1
# corporis	3
# corrupti	2
# culpa	3
# cum	1
# cumque	4
# cupiditate	2
# delectus	3
# deleniti	2
# deserunt	3
# dicta	1
# dignissimos	4
# distinctio	1
# dolor	5
# dolore	3
# doloremque	2
# dolores	2
# doloribus	2
# dolorum	1
# ducimus	2
# ea	5
# eaque	1
# earum	5
# eius	1
# eligendi	2
# enim	2
# eos	4
# error	3
# esse	1
# est	5
# eum	3
# eveniet	1
# ex	2
# excepturi	3
# exercitationem	2
# expedita	2
# explicabo	4
# facere	3
# facilis	1
# fuga	2
# fugiat	1
# fugit	1
# harum	1
# hic	2
# hic?	1
# id	3
# illum	4
# impedit	2
# in	1
# incidunt	4
# inventore	4
# ipsam	1
# ipsum	2
# iste	1
# itaque	1
# labore	1
# laboriosam	3
# laborum	1
# laudantium	2
# libero	4
# magnam	1
# magni	3
# maiores	4
# minima	3
# minus	3
# modi	1
# molestiae	3
# molestiae?	1
# mollitia	6
# nam	4
# natus	5
# necessitatibus	3
# nemo	1
# neque	1
# nihil	5
# nisi	3
# nobis	1
# nostrum	1
# nulla	2
# nulla?	1
# numquam	3
# obcaecati	2
# odio	2
# odit	2
# officia	4
# officiis	1
# omnis	4
# optio	1
# pariatur	5
# perferendis	1
# perspiciatis	2
# placeat	1
# porro	2
# possimus	2
# praesentium	3
# provident	5
# quae	3
# quaerat	2
# quam	3
# quas	1
# quasi	1
# quia	2
# quis	1
# quisquam	2
# quo	6
# quod	3
# quos	1
# ratione	3
# recusandae	1
# reiciendis	2
# rem	4
# repellat	4
# repellendus	2
# repellendus?	2
# reprehenderit	2
# reprehenderit?	1
# repudiandae	1
# rerum	2
# saepe	4
# sed	4
# sequi	1
# similique	4
# sint	3
# sit	4
# soluta	1
# suscipit	1
# tempora	4
# tempore	5
# temporibus	5
# tenetur	1
# totam	1
# ullam	1
# unde	3
# vel	6
# velit	1
# veniam	2
# veritatis	3
# vitae	4
# voluptas	4
# voluptate	2
# voluptates	4
# voluptatibus	4
# voluptatum	4

# %% [markdown]
# **Question subsidiaire.** Améliorer votre code (si besoin) pour que la ponctuation soit correctement prise en compte.

# %% [markdown]
# ## Pour aller plus loin
#
# Faites de même en utilisant les fichiers `notes_*.csv` pour calculer les moyennes par étudiant (identifié par son numéro d'étudiant, première colonne).
# Vous considérerez que les fichiers `notes_*.csv` contiennent une note par ligne et que les moyennes sont à calculer sans tenir compte de quelconques coefficients et en mélangeant toutes les matières.

# %%
# !chmod u+x *.py

# %%
# !cat notes_*.csv | ./mapper_notes.py
# Out:
# 21949510	STATS	10
# 21881510	BIG-DATA	19
# 22001510	ML	16
# 22001510	STATS	6
# 22001510	STATS	11
# 21881510	STATS	10
# 21881510	STATS	20
# 21881510	BIG-DATA	19
# 21991510	BIG-DATA	19
# 21949510	BIG-DATA	6
# 21881510	BIG-DATA	10
# 22001510	BIG-DATA	6
# 22001510	ML	16
# 21881510	ML	18
# 21991510	BIG-DATA	12
# 21949510	STATS	12
# 21881510	ML	7
# 21881510	ML	12
# 21881510	STATS	16
# 21881510	ML	15
# 21991510	ML	14
# 21881510	BIG-DATA	9
# 21949510	ML	18
# 21881510	ML	16
# 21949510	ML	18
# 21949510	BIG-DATA	8
# 21991510	ML	6
# 21949510	STATS	5
# 22001510	ML	15
# 21881510	BIG-DATA	20
# 21881510	BIG-DATA	18
# 22001510	STATS	18
# 22001510	ML	14
# 21991510	BIG-DATA	9
# 21881510	STATS	16
# 21991510	ML	6
# 21949510	STATS	11
# 22001510	STATS	9
# 21881510	STATS	14
# 21881510	BIG-DATA	12
# 21949510	BIG-DATA	5
# 22001510	STATS	18
# 22001510	BIG-DATA	10
# 22001510	ML	19
# 21949510	ML	9
# 21881510	STATS	17
# 21949510	STATS	20
# 21881510	STATS	14
# 21881510	STATS	8
# 21949510	ML	14
# 21881510	ML	7
# 21949510	ML	17
# 21949510	STATS	13
# 21949510	ML	12
# 21949510	ML	13
# 21949510	ML	20
# 22001510	STATS	17
# 21881510	ML	18
# 22001510	ML	11
# 21881510	ML	9
# 21949510	ML	20
# 21991510	BIG-DATA	19
# 22001510	BIG-DATA	16
# 21949510	STATS	7
# 21991510	STATS	11
# 21881510	ML	11
# 21991510	BIG-DATA	10
# 21949510	ML	5
# 21949510	STATS	17
# 21991510	ML	17
# 21949510	STATS	7
# 21881510	BIG-DATA	18
# 21949510	STATS	19
# 21949510	ML	6
# 21949510	BIG-DATA	10
# 21881510	BIG-DATA	7
# 21881510	STATS	10
# 21949510	BIG-DATA	19
# 22001510	BIG-DATA	11
# 21991510	BIG-DATA	9
# 21949510	STATS	16
# 22001510	ML	13
# 21991510	STATS	5
# 21881510	STATS	13
# 22001510	BIG-DATA	11
# 21991510	ML	20
# 21949510	BIG-DATA	15
# 22001510	STATS	14
# 21881510	ML	4
# 21991510	BIG-DATA	4
# 21949510	STATS	20
# 21991510	STATS	10
# 21949510	ML	7
# 21991510	STATS	12
# 21881510	ML	11
# 22001510	STATS	16
# 22001510	STATS	2
# 21881510	STATS	7
# 22001510	BIG-DATA	12
# 21991510	BIG-DATA	8

# %%
# !cat notes_*.csv | ./mapper_notes.py | sort | ./reducer_notes.py
# Out:
# 21881510	13.064516129032258
# 21949510	12.633333333333333
# 21991510	11.235294117647058
# 22001510	12.772727272727273

# %%
# !mapred streaming -file mapper_notes.py -mapper mapper_notes.py -file reducer_notes.py  -reducer reducer_notes.py -input /hdfs/input/notes_*.csv -output /hdfs/output_notes3
# Out:
# 2023-10-23 15:02:10,365 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [mapper_notes.py, reducer_notes.py] [] /tmp/streamjob2438078788322334696.jar tmpDir=null
# 2023-10-23 15:02:10,920 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2023-10-23 15:02:11,037 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2023-10-23 15:02:11,037 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2023-10-23 15:02:11,053 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-10-23 15:02:11,235 INFO mapred.FileInputFormat: Total input files to process : 5
# 2023-10-23 15:02:11,258 INFO mapreduce.JobSubmitter: number of splits:5
# 2023-10-23 15:02:11,505 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local354613490_0001
# 2023-10-23 15:02:11,505 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2023-10-23 15:02:11,917 INFO mapred.LocalDistributedCacheManager: Localized file:/content/mapper_notes.py as file:/tmp/hadoop-root/mapred/local/job_local354613490_0001_41cbe3a4-c3a1-4879-92be-a007d3223c6c/mapper_notes.py
# 2023-10-23 15:02:11,945 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reducer_notes.py as file:/tmp/hadoop-root/mapred/local/job_local354613490_0001_55e35748-2965-4930-aba8-fafd1e3b66cb/reducer_notes.py
# 2023-10-23 15:02:12,165 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2023-10-23 15:02:12,167 INFO mapreduce.Job: Running job: job_local354613490_0001
# 2023-10-23 15:02:12,177 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2023-10-23 15:02:12,181 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2023-10-23 15:02:12,199 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 15:02:12,199 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 15:02:12,319 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2023-10-23 15:02:12,323 INFO mapred.LocalJobRunner: Starting task: attempt_local354613490_0001_m_000000_0
# 2023-10-23 15:02:12,376 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 15:02:12,378 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 15:02:12,404 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 15:02:12,424 INFO mapred.MapTask: Processing split: file:/hdfs/input/notes_3.csv:0+366
# 2023-10-23 15:02:12,446 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 15:02:12,486 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 15:02:12,486 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 15:02:12,486 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 15:02:12,487 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 15:02:12,487 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 15:02:12,491 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 15:02:12,499 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_notes.py]
# 2023-10-23 15:02:12,506 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2023-10-23 15:02:12,517 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2023-10-23 15:02:12,519 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2023-10-23 15:02:12,519 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2023-10-23 15:02:12,520 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2023-10-23 15:02:12,520 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2023-10-23 15:02:12,525 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2023-10-23 15:02:12,525 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2023-10-23 15:02:12,525 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-10-23 15:02:12,525 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2023-10-23 15:02:12,526 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-10-23 15:02:12,527 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-10-23 15:02:12,558 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:12,558 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:12,648 INFO streaming.PipeMapRed: Records R/W=20/1
# 2023-10-23 15:02:12,653 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 15:02:12,654 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 15:02:12,657 INFO mapred.LocalJobRunner:
# 2023-10-23 15:02:12,657 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 15:02:12,658 INFO mapred.MapTask: Spilling map output
# 2023-10-23 15:02:12,658 INFO mapred.MapTask: bufstart = 0; bufend = 234; bufvoid = 104857600
# 2023-10-23 15:02:12,658 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214320(104857280); length = 77/6553600
# 2023-10-23 15:02:12,672 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 15:02:12,692 INFO mapred.Task: Task:attempt_local354613490_0001_m_000000_0 is done. And is in the process of committing
# 2023-10-23 15:02:12,696 INFO mapred.LocalJobRunner: Records R/W=20/1
# 2023-10-23 15:02:12,696 INFO mapred.Task: Task 'attempt_local354613490_0001_m_000000_0' done.
# 2023-10-23 15:02:12,710 INFO mapred.Task: Final Counters for attempt_local354613490_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=3238
# 		FILE: Number of bytes written=643553
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=20
# 		Map output records=20
# 		Map output bytes=234
# 		Map output materialized bytes=280
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=20
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=384827392
# 	File Input Format Counters
# 		Bytes Read=382
# 2023-10-23 15:02:12,710 INFO mapred.LocalJobRunner: Finishing task: attempt_local354613490_0001_m_000000_0
# 2023-10-23 15:02:12,710 INFO mapred.LocalJobRunner: Starting task: attempt_local354613490_0001_m_000001_0
# 2023-10-23 15:02:12,713 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 15:02:12,713 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 15:02:12,714 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 15:02:12,718 INFO mapred.MapTask: Processing split: file:/hdfs/input/notes_0.csv:0+359
# 2023-10-23 15:02:12,722 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 15:02:12,780 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 15:02:12,780 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 15:02:12,780 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 15:02:12,780 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 15:02:12,780 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 15:02:12,790 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 15:02:12,802 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_notes.py]
# 2023-10-23 15:02:12,830 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:12,833 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:12,914 INFO streaming.PipeMapRed: Records R/W=20/1
# 2023-10-23 15:02:12,918 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 15:02:12,918 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 15:02:12,919 INFO mapred.LocalJobRunner:
# 2023-10-23 15:02:12,920 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 15:02:12,920 INFO mapred.MapTask: Spilling map output
# 2023-10-23 15:02:12,920 INFO mapred.MapTask: bufstart = 0; bufend = 236; bufvoid = 104857600
# 2023-10-23 15:02:12,920 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214320(104857280); length = 77/6553600
# 2023-10-23 15:02:12,921 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 15:02:12,930 INFO mapred.Task: Task:attempt_local354613490_0001_m_000001_0 is done. And is in the process of committing
# 2023-10-23 15:02:12,931 INFO mapred.LocalJobRunner: Records R/W=20/1
# 2023-10-23 15:02:12,931 INFO mapred.Task: Task 'attempt_local354613490_0001_m_000001_0' done.
# 2023-10-23 15:02:12,932 INFO mapred.Task: Final Counters for attempt_local354613490_0001_m_000001_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=4032
# 		FILE: Number of bytes written=643867
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=20
# 		Map output records=20
# 		Map output bytes=236
# 		Map output materialized bytes=282
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=20
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=35
# 		Total committed heap usage (bytes)=384827392
# 	File Input Format Counters
# 		Bytes Read=375
# 2023-10-23 15:02:12,935 INFO mapred.LocalJobRunner: Finishing task: attempt_local354613490_0001_m_000001_0
# 2023-10-23 15:02:12,935 INFO mapred.LocalJobRunner: Starting task: attempt_local354613490_0001_m_000002_0
# 2023-10-23 15:02:12,937 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 15:02:12,937 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 15:02:12,937 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 15:02:12,939 INFO mapred.MapTask: Processing split: file:/hdfs/input/notes_4.csv:0+353
# 2023-10-23 15:02:12,951 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 15:02:12,991 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 15:02:13,002 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 15:02:13,002 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 15:02:13,002 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 15:02:13,002 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 15:02:13,007 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 15:02:13,012 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_notes.py]
# 2023-10-23 15:02:13,041 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:13,041 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:13,102 INFO streaming.PipeMapRed: Records R/W=20/1
# 2023-10-23 15:02:13,109 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 15:02:13,112 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 15:02:13,113 INFO mapred.LocalJobRunner:
# 2023-10-23 15:02:13,113 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 15:02:13,113 INFO mapred.MapTask: Spilling map output
# 2023-10-23 15:02:13,113 INFO mapred.MapTask: bufstart = 0; bufend = 233; bufvoid = 104857600
# 2023-10-23 15:02:13,113 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214320(104857280); length = 77/6553600
# 2023-10-23 15:02:13,115 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 15:02:13,131 INFO mapred.Task: Task:attempt_local354613490_0001_m_000002_0 is done. And is in the process of committing
# 2023-10-23 15:02:13,133 INFO mapred.LocalJobRunner: Records R/W=20/1
# 2023-10-23 15:02:13,134 INFO mapred.Task: Task 'attempt_local354613490_0001_m_000002_0' done.
# 2023-10-23 15:02:13,139 INFO mapred.Task: Final Counters for attempt_local354613490_0001_m_000002_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=4820
# 		FILE: Number of bytes written=644178
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=20
# 		Map output records=20
# 		Map output bytes=233
# 		Map output materialized bytes=279
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=20
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=7
# 		Total committed heap usage (bytes)=384827392
# 	File Input Format Counters
# 		Bytes Read=369
# 2023-10-23 15:02:13,140 INFO mapred.LocalJobRunner: Finishing task: attempt_local354613490_0001_m_000002_0
# 2023-10-23 15:02:13,141 INFO mapred.LocalJobRunner: Starting task: attempt_local354613490_0001_m_000003_0
# 2023-10-23 15:02:13,144 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 15:02:13,150 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 15:02:13,150 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 15:02:13,153 INFO mapred.MapTask: Processing split: file:/hdfs/input/notes_1.csv:0+347
# 2023-10-23 15:02:13,161 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 15:02:13,185 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 15:02:13,187 INFO mapreduce.Job: Job job_local354613490_0001 running in uber mode : false
# 2023-10-23 15:02:13,199 INFO mapreduce.Job:  map 100% reduce 0%
# 2023-10-23 15:02:13,202 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 15:02:13,202 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 15:02:13,204 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 15:02:13,204 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 15:02:13,217 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 15:02:13,224 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_notes.py]
# 2023-10-23 15:02:13,246 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:13,246 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:13,297 INFO streaming.PipeMapRed: Records R/W=20/1
# 2023-10-23 15:02:13,301 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 15:02:13,302 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 15:02:13,303 INFO mapred.LocalJobRunner:
# 2023-10-23 15:02:13,303 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 15:02:13,303 INFO mapred.MapTask: Spilling map output
# 2023-10-23 15:02:13,303 INFO mapred.MapTask: bufstart = 0; bufend = 233; bufvoid = 104857600
# 2023-10-23 15:02:13,303 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214320(104857280); length = 77/6553600
# 2023-10-23 15:02:13,307 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 15:02:13,312 INFO mapred.Task: Task:attempt_local354613490_0001_m_000003_0 is done. And is in the process of committing
# 2023-10-23 15:02:13,314 INFO mapred.LocalJobRunner: Records R/W=20/1
# 2023-10-23 15:02:13,314 INFO mapred.Task: Task 'attempt_local354613490_0001_m_000003_0' done.
# 2023-10-23 15:02:13,315 INFO mapred.Task: Final Counters for attempt_local354613490_0001_m_000003_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=5602
# 		FILE: Number of bytes written=644489
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=20
# 		Map output records=20
# 		Map output bytes=233
# 		Map output materialized bytes=279
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=20
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=6
# 		Total committed heap usage (bytes)=384827392
# 	File Input Format Counters
# 		Bytes Read=363
# 2023-10-23 15:02:13,315 INFO mapred.LocalJobRunner: Finishing task: attempt_local354613490_0001_m_000003_0
# 2023-10-23 15:02:13,315 INFO mapred.LocalJobRunner: Starting task: attempt_local354613490_0001_m_000004_0
# 2023-10-23 15:02:13,316 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 15:02:13,316 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 15:02:13,317 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 15:02:13,324 INFO mapred.MapTask: Processing split: file:/hdfs/input/notes_2.csv:0+328
# 2023-10-23 15:02:13,334 INFO mapred.MapTask: numReduceTasks: 1
# 2023-10-23 15:02:13,377 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-10-23 15:02:13,377 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-10-23 15:02:13,377 INFO mapred.MapTask: soft limit at 83886080
# 2023-10-23 15:02:13,377 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-10-23 15:02:13,377 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-10-23 15:02:13,386 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-10-23 15:02:13,401 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./mapper_notes.py]
# 2023-10-23 15:02:13,426 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:13,426 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:13,561 INFO streaming.PipeMapRed: Records R/W=20/1
# 2023-10-23 15:02:13,565 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 15:02:13,566 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 15:02:13,566 INFO mapred.LocalJobRunner:
# 2023-10-23 15:02:13,566 INFO mapred.MapTask: Starting flush of map output
# 2023-10-23 15:02:13,566 INFO mapred.MapTask: Spilling map output
# 2023-10-23 15:02:13,566 INFO mapred.MapTask: bufstart = 0; bufend = 235; bufvoid = 104857600
# 2023-10-23 15:02:13,566 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214320(104857280); length = 77/6553600
# 2023-10-23 15:02:13,568 INFO mapred.MapTask: Finished spill 0
# 2023-10-23 15:02:13,579 INFO mapred.Task: Task:attempt_local354613490_0001_m_000004_0 is done. And is in the process of committing
# 2023-10-23 15:02:13,581 INFO mapred.LocalJobRunner: Records R/W=20/1
# 2023-10-23 15:02:13,581 INFO mapred.Task: Task 'attempt_local354613490_0001_m_000004_0' done.
# 2023-10-23 15:02:13,582 INFO mapred.Task: Final Counters for attempt_local354613490_0001_m_000004_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=6365
# 		FILE: Number of bytes written=644802
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=20
# 		Map output records=20
# 		Map output bytes=235
# 		Map output materialized bytes=281
# 		Input split bytes=80
# 		Combine input records=0
# 		Spilled Records=20
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=5
# 		Total committed heap usage (bytes)=384827392
# 	File Input Format Counters
# 		Bytes Read=344
# 2023-10-23 15:02:13,583 INFO mapred.LocalJobRunner: Finishing task: attempt_local354613490_0001_m_000004_0
# 2023-10-23 15:02:13,583 INFO mapred.LocalJobRunner: map task executor complete.
# 2023-10-23 15:02:13,588 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2023-10-23 15:02:13,589 INFO mapred.LocalJobRunner: Starting task: attempt_local354613490_0001_r_000000_0
# 2023-10-23 15:02:13,597 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-10-23 15:02:13,597 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-10-23 15:02:13,597 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-10-23 15:02:13,603 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@9301476
# 2023-10-23 15:02:13,604 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-10-23 15:02:13,645 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2382574336, maxSingleShuffleLimit=595643584, mergeThreshold=1572499072, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-10-23 15:02:13,672 INFO reduce.EventFetcher: attempt_local354613490_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-10-23 15:02:13,731 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local354613490_0001_m_000001_0 decomp: 278 len: 282 to MEMORY
# 2023-10-23 15:02:13,741 INFO reduce.InMemoryMapOutput: Read 278 bytes from map-output for attempt_local354613490_0001_m_000001_0
# 2023-10-23 15:02:13,744 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 278, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->278
# 2023-10-23 15:02:13,749 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local354613490_0001_m_000004_0 decomp: 277 len: 281 to MEMORY
# 2023-10-23 15:02:13,752 INFO reduce.InMemoryMapOutput: Read 277 bytes from map-output for attempt_local354613490_0001_m_000004_0
# 2023-10-23 15:02:13,752 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 277, inMemoryMapOutputs.size() -> 2, commitMemory -> 278, usedMemory ->555
# 2023-10-23 15:02:13,756 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local354613490_0001_m_000002_0 decomp: 275 len: 279 to MEMORY
# 2023-10-23 15:02:13,762 INFO reduce.InMemoryMapOutput: Read 275 bytes from map-output for attempt_local354613490_0001_m_000002_0
# 2023-10-23 15:02:13,763 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 275, inMemoryMapOutputs.size() -> 3, commitMemory -> 555, usedMemory ->830
# 2023-10-23 15:02:13,764 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local354613490_0001_m_000003_0 decomp: 275 len: 279 to MEMORY
# 2023-10-23 15:02:13,768 INFO reduce.InMemoryMapOutput: Read 275 bytes from map-output for attempt_local354613490_0001_m_000003_0
# 2023-10-23 15:02:13,768 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 275, inMemoryMapOutputs.size() -> 4, commitMemory -> 830, usedMemory ->1105
# 2023-10-23 15:02:13,770 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local354613490_0001_m_000000_0 decomp: 276 len: 280 to MEMORY
# 2023-10-23 15:02:13,770 INFO reduce.InMemoryMapOutput: Read 276 bytes from map-output for attempt_local354613490_0001_m_000000_0
# 2023-10-23 15:02:13,771 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 276, inMemoryMapOutputs.size() -> 5, commitMemory -> 1105, usedMemory ->1381
# 2023-10-23 15:02:13,771 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2023-10-23 15:02:13,774 INFO mapred.LocalJobRunner: 5 / 5 copied.
# 2023-10-23 15:02:13,774 INFO reduce.MergeManagerImpl: finalMerge called with 5 in-memory map-outputs and 0 on-disk map-outputs
# 2023-10-23 15:02:13,787 INFO mapred.Merger: Merging 5 sorted segments
# 2023-10-23 15:02:13,788 INFO mapred.Merger: Down to the last merge-pass, with 5 segments left of total size: 1326 bytes
# 2023-10-23 15:02:13,799 INFO reduce.MergeManagerImpl: Merged 5 segments, 1381 bytes to disk to satisfy reduce memory limit
# 2023-10-23 15:02:13,800 INFO reduce.MergeManagerImpl: Merging 1 files, 1377 bytes from disk
# 2023-10-23 15:02:13,801 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2023-10-23 15:02:13,801 INFO mapred.Merger: Merging 1 sorted segments
# 2023-10-23 15:02:13,802 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 1362 bytes
# 2023-10-23 15:02:13,809 INFO mapred.LocalJobRunner: 5 / 5 copied.
# 2023-10-23 15:02:13,830 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reducer_notes.py]
# 2023-10-23 15:02:13,832 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-10-23 15:02:13,834 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-10-23 15:02:13,886 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:13,886 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:13,890 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-10-23 15:02:13,932 INFO streaming.PipeMapRed: Records R/W=100/1
# 2023-10-23 15:02:13,940 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-10-23 15:02:13,941 INFO streaming.PipeMapRed: mapRedFinished
# 2023-10-23 15:02:13,943 INFO mapred.Task: Task:attempt_local354613490_0001_r_000000_0 is done. And is in the process of committing
# 2023-10-23 15:02:13,951 INFO mapred.LocalJobRunner: 5 / 5 copied.
# 2023-10-23 15:02:13,957 INFO mapred.Task: Task attempt_local354613490_0001_r_000000_0 is allowed to commit now
# 2023-10-23 15:02:13,958 INFO output.FileOutputCommitter: Saved output of task 'attempt_local354613490_0001_r_000000_0' to file:/hdfs/output_notes3
# 2023-10-23 15:02:13,961 INFO mapred.LocalJobRunner: Records R/W=100/1 > reduce
# 2023-10-23 15:02:13,962 INFO mapred.Task: Task 'attempt_local354613490_0001_r_000000_0' done.
# 2023-10-23 15:02:13,962 INFO mapred.Task: Final Counters for attempt_local354613490_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=9303
# 		FILE: Number of bytes written=646303
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=4
# 		Reduce shuffle bytes=1401
# 		Reduce input records=100
# 		Reduce output records=4
# 		Spilled Records=100
# 		Shuffled Maps =5
# 		Failed Shuffles=0
# 		Merged Map outputs=5
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=384827392
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=124
# 2023-10-23 15:02:13,963 INFO mapred.LocalJobRunner: Finishing task: attempt_local354613490_0001_r_000000_0
# 2023-10-23 15:02:13,963 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2023-10-23 15:02:14,202 INFO mapreduce.Job:  map 100% reduce 100%
# 2023-10-23 15:02:14,202 INFO mapreduce.Job: Job job_local354613490_0001 completed successfully
# 2023-10-23 15:02:14,218 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=33360
# 		FILE: Number of bytes written=3867192
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=100
# 		Map output records=100
# 		Map output bytes=1171
# 		Map output materialized bytes=1401
# 		Input split bytes=400
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=4
# 		Reduce shuffle bytes=1401
# 		Reduce input records=100
# 		Reduce output records=4
# 		Spilled Records=200
# 		Shuffled Maps =5
# 		Failed Shuffles=0
# 		Merged Map outputs=5
# 		GC time elapsed (ms)=53
# 		Total committed heap usage (bytes)=2308964352
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=1833
# 	File Output Format Counters
# 		Bytes Written=124
# 2023-10-23 15:02:14,219 INFO streaming.StreamJob: Output directory: /hdfs/output_notes3

# %%
# !hadoop fs -cat /hdfs/output_notes3/part-00000
# Out:
# 21881510	13.064516129032258
# 21949510	12.633333333333333
# 21991510	11.235294117647058
# 22001510	12.772727272727273
